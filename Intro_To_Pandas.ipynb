# %%
import pandas as pd
df=pd.read_csv(r"D:\UPSKILL 2025\Python Packages\bwf_historic_rankings.csv",low_memory=False)
df
# Out:
#         Unnamed: 0  rank  delta_rank country_code  \
# 0                0     1         0.0          DEN
# 1                1     2         0.0          INA
# 2                2     3         0.0          JPN
# 3                3     4         1.0          THA
# 4                4     5         1.0          CHN
# ...            ...   ...         ...          ...
# 888495      888595    96         NaN          NaN
# 888496      888596    97         NaN          NaN
# 888497      888597    98         NaN          NaN
# 888498      888598    99         NaN          NaN
# 888499      888599   100         NaN          NaN
#
#                                           name     id  points  \
# 0                               VIKTOR AXELSEN  25831  107455
# 1                     ANTHONY SINISUKA GINTING  95661   86611
# 2                                KODAI NARAOKA  62063   82015
# 3                           KUNLAVUT VITIDSARN  64032   79778
# ...

# %%
#this gives us the max points 
df['points'].max()
# Out:
# 122606

# %%
#return the dates when the matches are drawn:
df['date'][df['draw']=='MS']
# Out:
# 0         24-10-2023
# 1         24-10-2023
# 2         24-10-2023
# 3         24-10-2023
# 4         24-10-2023
#              ...
# 888095    01-01-1990
# 888096    01-01-1990
# 888097    01-01-1990
# 888098    01-01-1990
# 888099    01-01-1990
# Name: date, Length: 177700, dtype: object

# %%
df['points'].mean()
# Out:
# np.float64(24801.090606640406)

# %%
#the process of cleaning messy data is called data munging or data wrangling

# %%
#when we have nan in dataset its better to replace it with 0
df.fillna(0,inplace=True)
df
# Out:
#         Unnamed: 0  rank  delta_rank country_code  \
# 0                0     1         0.0          DEN
# 1                1     2         0.0          INA
# 2                2     3         0.0          JPN
# 3                3     4         1.0          THA
# 4                4     5         1.0          CHN
# ...            ...   ...         ...          ...
# 888495      888595    96         0.0            0
# 888496      888596    97         0.0            0
# 888497      888597    98         0.0            0
# 888498      888598    99         0.0            0
# 888499      888599   100         0.0            0
#
#                                           name     id  points  \
# 0                               VIKTOR AXELSEN  25831  107455
# 1                     ANTHONY SINISUKA GINTING  95661   86611
# 2                                KODAI NARAOKA  62063   82015
# 3                           KUNLAVUT VITIDSARN  64032   79778
# ...
